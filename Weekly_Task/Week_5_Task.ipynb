# %% [markdown]
# <center><h1>Raj Panchasara</h1></center>
# <center><h1>23010101185</h1></center><br>
# <center><h2>Test the model on the test dataset and compute metrics.</h2></center>
# <center><h2>Check for overfiRng or underfiRng.</h2></center>

# %% [markdown]
# # Week 5 Task :

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Load the saved model

# %%
import joblib

model = joblib.load("cardio_model.pkl")

# %%
import joblib

obj = joblib.load("cardio_model.pkl")
print(type(obj))
# Out:
# <class 'list'>

# %%
print(len(obj))
print(type(obj[0]))
# Out:
# 10
# <class 'dict'>

# %% [markdown]
# ## Check for overfittng or underfittng.

# %%
def check_fit(y_train, y_train_pred, y_test, y_test_pred):
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    print("Training Accuracy :", round(train_acc, 4))
    print("Testing Accuracy  :", round(test_acc, 4))

    if train_acc > 0.90 and test_acc < train_acc - 0.10:
        print("Model is OVERFITTING")
    elif train_acc < 0.70 and test_acc < 0.70:
        print("Model is UNDERFITTING")
    else:
        print("Model is WELL FITTED")

    return train_acc, test_acc

# %%
prediction = model.predict(sample)
print("Prediction:", prediction)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 prediction = model.predict(sample)
#       2 print("Prediction:", prediction)
#
# AttributeError: 'list' object has no attribute 'predict'
